# %% [markdown]
# ##  **Text Processing**

# %% [markdown]
# **What is Text Processing?**

# %% [markdown]
# "*The term text processing refers to the automation of analyzing electronic text. This allows machine learning models to get structured information about the text to use for analysis, manipulation of the text, or to generate new text. Text processing is also one of the most common tasks used in machine learning applications such as language translation, sentiment analysis, spam filtering, and many others. Text processing is very similiar to natural language processing(NLP) with the main difference being that text processing is the analysis, manipulation, and generation of text; while natural language processing refers to the ability of a computer to understand human language in a valuable way*". (DataRobot, 2020)
# <br>
# <br>
# <br>
# *Reference:*<br>
# DataRobot. *Text processing: what, why, and how*, 06 August 2020<br>
# [Online] Available at:<br>
# https://www.datarobot.com/blog/text-processing-what-why-and-how/#:~:text=What's%20the%20difference%20between%20text,language%20in%20a%20valuable%20way. <br>
# [Accessed 28 June 2023]

# %% [markdown]
# **Advantages & Disadvantages**

# %% [markdown]
# The use of text processing into our python code does have some benefits and downsides to consider when using it in our analysis. So let's discuss some of the advantages and disadvantages that text processing brings to our analysis. These advantages include: "*speedy editing and formatting; improved accuracy; increased efficiency; etc*" (*Advantages and Disadvantages of Word Processing*, AspiringYouths). While some disadvantages include: "*technical problems; dependence on technology; formatting challenges; etc*" (*Advantages and Disadvantages of Word Processing*, AspiringYouths).
# <br>
# <br>
# <br>
# *Reference:* <br>
# AspiringYouths. *Advantages and Disadvantages of Word Processing*<br>
# [Online] Available at:<br>
# https://aspiringyouths.com/advantages-disadvantages/word-processing/ <br>
# [Accessed 28 June 2023]

# %% [markdown]
# **Techniques of Text Processing**

# %% [markdown]
# There are four types of text processing techniques, these being: *Topic Analysis; Sentiment Analysis; Intent Detection; and Language Classification*. With some examples of where text processing techniques could be used are in:
# - **Topic Analysis:** "*this technique interprets and categorizes large collections of text into topics or themes.*" <br>**For Example:** "*helping to associate currency symbols, numbers, related terms (affordable, pricey) and expressions (it costs a fortune) with the word price*" (DataRobot, 2020).<br><br>
# - **Sentiment Analysis:** "*this function automatically detects the emotional undertones of text and classifies them as positive, negative, or neutral.*" <br>**For Example:** "*used in reviews, blogs, forums, and other online media to determine if your customers are happy with their purchases*" (DataRobot, 2020).<br><br>
# - **Intent Detection:** "*this classification model detects the intent, purpose, or goal of the text.*" <br>**For Example:** "*to determine whether the intent is to gain information, make a purchase, or unsubscribe from the company*" (DataRobot, 2020).<br><br>
# - **Language Classification:** "*this classifies text based on which language it’s written in.*"<br>**For Example:** "*'My Hero Academia' is classified in the English language classification; while 'Shingeki no Kyojin' is classified in the Japanese language classification*" (DataRobot, 2020).<br><br>
# <br>
# *Reference:*<br>
# DataRobot. *Text processing: what, why, and how*, 06 August 2020<br>
# [Online] Available at:<br>
# https://www.datarobot.com/blog/text-processing-what-why-and-how/#:~:text=What's%20the%20difference%20between%20text,language%20in%20a%20valuable%20way. <br>
# [Accessed 28 June 2023]

# %% [markdown]
# ##  **Dataset**

# %% [markdown]
# *What dataset is used in this analysis?* I've chosen the **Pfizer Vaccine Tweets** dataset (Preda, 2021).
#
# *Why is this dataset perfect for text processing?* This is a text-based dataset that comprises of data from recent twitter tweets about the Pfizer & BioNTech vaccine. The context also states that the purpose of this dataset is to show all the verfified and unverified users that made a tweet relating to the Pfizer & BioNTech vaccine, and that the dataset is made for NLP tasks. LDA which will be performed is a subset of NLP, which makes this dataset suitable in our analysis. This dataset is also a recent dataset with updated data, which will be perfect for the analysis performed in this assignment.
#
# **Reference for Dataset**
#
# Preda, G.(2021) *'Pfizer Vaccine Tweets'*. [Online]. Available at:<br>
# https://www.kaggle.com/datasets/gpreda/pfizer-vaccine-tweets<br>
# [Accessed 29 June 2023]

# %% [markdown]
# ##  **Analysis**

# %% [markdown]
# In this analysis, we are using Latent Dirichlet Allocation (LDA). "*LDA, which is a popular topic modeling algorithm, is when documents are represented as a mixture of topics and a topic is a bunch of words. Those topics reside within a hidden, also known as a latent layer. LDA would than look at a document to determine a set of topics that are likely to have generated that collection of words. So, if a document uses certain words that are contained in a topic, the document is said to be about that specific topic. Using this topic modeling aglorithm can provide an advantage in our analysis by tuning the LDA parameters to fit different dataset shapes, one can explore topic formation and resulting document clusters*" (*Latent Dirichlet Allocation (LDA)*, MarketMuse). LDA implementation consists of six steps: *loading the data; data cleaning; exploratory data analysis; data pre-processing; LDA model training; and analysing LDA model results.* All of these will be explained in later in the steps for the analysis.
# <br>
# <br>
# <br>
# *Reference:*<br>
# MarketMuse. *Latent Dirichlet Allocation (LDA)*<br>
# [Online] Available at:<br>
# https://blog.marketmuse.com/glossary/latent-dirichlet-allocation-definition/ <br>
# [Accessed 27 June 2023]

# %% [markdown]
# ##  **Steps of the Analysis**

# %% [markdown]
# ***What Steps should be included in this Analysis for:***
# - ***Loading the Data:*** this step is pretty self explanatory, we load the data in the dataset, by reading the text data from the CSV file and we import the appropriate libraries that will be used later in our analysis.<br><br>
# - ***Data Cleaning:*** in this step we will be looking for any null or NaN values that lie in the data, and if there is we remove them.<br><br>
# - ***Exploratory Data Analysis:*** in this step we focus on reading the data by displaying information about the dataset being the size, shape, attribute data types, but also if there needs to be any changes made to that given dataset. We also represent the data visually in graph format using histographs, a correlation graph, a scatterplot, and a countplot. <br><br>
# - ***Data Pre-processing:*** before we incorporate LDA into our analysis, we first need to transform the text data in the dataset. Here the text data will go through a series of steps from removing any stop words(common words), tokenisation, stemming and lemmatisation.<br><br>
# - ***LDA Model Training:*** here we set up our X and Y variables that will used later in our analysis and in the train and test splits. Using these variables in the training and test splits, the test size is 30%, the remaining 70% is the train size, and random state is 42 which means the output is the same each time. Once the training and test splits have been declared, they will go through a process of countvectorisation and tf-idf.<br><br>
# - ***LDA Model Results:*** once we incoporate LDA into our analysis, we than need to analyse the results of the model. The Naive Bayes algorithm will be used, and We will do this by passing it into a pipeline. Using this pipeline we also fit the X train and y train to perform calculations on the accuracy and other scores of these predictions.

# %% [markdown]
# ##  **Evaluation of the Model**

# %% [markdown]
# For this part we will be making comparisons on the accuracy of the predictions and the accuracy of the model. We will be using a recall score, F1 score, precision score, accuracy score, pipeline score and a confusion matrix. For the first calculation of the pipeline score it calculated that the accuracy of the model is 0.91167574107683 accurate. Next for the accuracy of predictions, the accuracy score was also 0.91167574107683, which is really good. While the confusing matrix on these predictions came back was [3014,    0],[ 292,    0]; this means that the data lies on the True Positive and False Negative quadrants. True Positive means that from these 3014 predictions, it was predicted as true and is actually true. While, False Negative means that 292 of these predictions are predicted as negative but is actually positive. Other scores calculated on the accuracy of these predictions were the recall score, F1 score, and the precision score. The recall score score came back as 1.00, which is good. The F1 score came back as 0.95, of 95% which is really good. While the precision score came back as 0.91, which is also very good.
#
# *Conclusion:* this concludes that the use of LDA, pipelines and other analysis techniques improved the overall accuracy of the model and its predictions. LDA ultimately improved this model by enabling it to build data points and estimate on the probabilities. While pipelines made it easier to conduct analysis by helping to organise your workflows and makes your process faster

# %% [markdown]
# ##  **Code**

# %% [markdown]
# ###  **Loading the Data**

# %% [markdown]
# **Import Libraries**
#
# For basic Exploratory Data Analysis (EDA) and visualisation of graphs we currently use four imports. Both *numpy* and *pandas* main purpose is for treating and displaying data from the CSV file, and *matplotlib.pyplot* and *seaborn* is for visualising the data in graph form.

# %%
import numpy as np # USED FOR STANDARD LINEAR ALGEBRA
import pandas as pd # USED FOR DATA PROCESSING AND READING DATA FROM THE CSV FILE
import matplotlib.pyplot as plt # USED FOR DISPLAYING THE INFORMATION OF GRAPHS: THE LABELS, THE VALUES, ETC.
import seaborn as sns # USED TO DISPLAY THE GRAPHICS OF GRAPHS

# %% [markdown]
# **Loading the Dataset**
#
# We load the dataset from the vaccination_tweet.csv file

# %%
# THIS READS THE DATA FROM THE CSV FILE
dataset = pd.read_csv('vaccination_tweets.csv')

# %% [markdown]
# ###  **Data Cleaning**

# %% [markdown]
# **Removal of Null and NaN Values**
#
# In this step we will see if there is any null and nunique values

# %%
# THIS RETURNS THE NUMBER OF UNIQUES VALUES IN EACH COLUMN
dataset.nunique(axis=0)
# Out:
# id                  11020
# user_name            7202
# user_location        3136
# user_description     6915
# user_created         7157
# user_followers       3674
# user_friends         2757
# user_favourites      6122
# user_verified           2
# date                11008
# text                11013
# hashtags             4657
# source                 64
# retweets               78
# favorites             181
# is_retweet              1
# dtype: int64

# %%
# THIS LETS US KNOW IF THERE ARE ANY NULL OR EMPTY VALUES IN THIS DATASET
# ITS TRUE MEANING WE NEED TO REMOVE NULL VALUES
dataset.isnull().values.any()
# Out:
# True

# %%
# THIS DISPLAYS THE PERCENTAGE OF NULL VALUES IN EACH COLUMN
# FROM ALL THE COLUMNS, 'user_location' AND 'hashtags' ARE THE ONLY COLUMNS THAT HAVE NULL VALUES
100 * dataset.isnull().sum() / len(dataset)
# Out:
# id                   0.000000
# user_name            0.000000
# user_location       20.598911
# user_description     6.161525
# user_created         0.000000
# user_followers       0.000000
# user_friends         0.000000
# user_favourites      0.000000
# user_verified        0.000000
# date                 0.000000
# text                 0.000000
# hashtags            23.430127
# source               0.009074
# retweets             0.000000
# favorites            0.000000
# is_retweet           0.000000
# dtype: float64

# %%
# NOW WE WILL REMOVE ALL THE NULL VALUES IN THE DATASET
dataset.dropna(how="any", inplace=True, axis=1)

# %%
# WE DOUBLE CHECK IF THERE IS STILL NULL VALUES
dataset.isnull().values.any()
# Out:
# False

# %%
# THIS DISPLAYS THE TOTAL NUMBER OF NAN (NOT A NUMBER) VALUES
dataset.isna().sum()
# Out:
# id                 0
# user_name          0
# user_created       0
# user_followers     0
# user_friends       0
# user_favourites    0
# user_verified      0
# date               0
# text               0
# retweets           0
# favorites          0
# is_retweet         0
# dtype: int64

# %% [markdown]
# ###  **Exploratory Data Analysis**

# %% [markdown]
# In this step we will display the data to see the size and shape of the dataset, visualise the data, or if we need to make any changes to the dataset.

# %%
# THIS DISPLAYS THE COLUMN NAMES
dataset.columns
# Out:
# Index(['id', 'user_name', 'user_created', 'user_followers', 'user_friends',
#        'user_favourites', 'user_verified', 'date', 'text', 'retweets',
#        'favorites', 'is_retweet'],
#       dtype='object')

# %%
# THIS DISPLAYS THE FIRST 5 ROWS OF THE DATASET
dataset.head()
# Out:
#                     id             user_name         user_created  \
# 0  1340539111971516416            Rachel Roh  2009-04-08 17:52:46
# 1  1338158543359250433           Albert Fong  2009-09-21 15:27:30
# 2  1337858199140118533              eli🇱🇹🇪🇺👌  2020-06-25 23:30:28
# 3  1337855739918835717         Charles Adler  2008-09-10 11:28:53
# 4  1337854064604966912  Citizen News Channel  2020-04-23 17:58:42
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                   date                                               text  \
# 0  2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# ...

# %%
# THIS DESCRIBES THE DATASET AND PROVIDES NUMERICAL VALUES LIKE MEAN, STANDARD DEVIATION, ETC.
dataset.describe()
# Out:
#                  id  user_followers   user_friends  user_favourites  \
# count  1.102000e+04    1.102000e+04   11020.000000     1.102000e+04
# mean   1.372977e+18    3.518827e+04    1170.470236     1.533289e+04
# std    3.311622e+16    2.942509e+05    2798.429673     4.944401e+04
# min    1.337728e+18    0.000000e+00       0.000000     0.000000e+00
# 25%    1.347623e+18    1.110000e+02     164.000000     4.360000e+02
# 50%    1.360274e+18    4.790000e+02     460.000000     2.323500e+03
# 75%    1.395234e+18    2.171250e+03    1221.000000     1.114075e+04
# max    1.463244e+18    1.371493e+07  103226.000000     1.213794e+06
#
#            retweets     favorites
# count  11020.000000  11020.000000
# mean       1.360436      7.510617
# std       11.364732     51.192608
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      1.000000
# 75%        1.000000      4.000000
# max      678.000000   2315.000000

# %%
# THIS DISPLAYS THE NUMBER OF COLUMNS, ROWS, AND VALUES OF THE DATASET
dataset.info
# Out:
# <bound method DataFrame.info of                         id             user_name         user_created  \
# 0      1340539111971516416            Rachel Roh  2009-04-08 17:52:46
# 1      1338158543359250433           Albert Fong  2009-09-21 15:27:30
# 2      1337858199140118533              eli🇱🇹🇪🇺👌  2020-06-25 23:30:28
# 3      1337855739918835717         Charles Adler  2008-09-10 11:28:53
# 4      1337854064604966912  Citizen News Channel  2020-04-23 17:58:42
# ...                    ...                   ...                  ...
# 11015  1460932683630977025                theSun  2009-07-29 01:58:44
# 11016  1460809350792896516                 Sujan  2013-01-28 11:48:20
# 11017  1460581918295031809                theSun  2009-07-29 01:58:44
# 11018  1460344277951782922      Aleksejs Jackovs  2012-08-13 13:47:03
# 11019  1460208097956225028                theSun  2009-07-29 01:58:44
#
#        user_followers  user_friends  user_favourites  user_verified  \
# ...

# %%
# THIS ALSO DISPLAYS THE SIZE OF THE DATASET BEING THE NUMBER OF ROWS AND COLUMNS
dataset.shape
# Out:
# (11020, 12)

# %%
# THIS DISPLAYS ALL THE DATASET ATTRIBUTES' DATA TYPES
dataset.dtypes
# Out:
# id                  int64
# user_name          object
# user_created       object
# user_followers      int64
# user_friends        int64
# user_favourites     int64
# user_verified        bool
# date               object
# text               object
# retweets            int64
# favorites           int64
# is_retweet           bool
# dtype: object

# %%
# LETS CHANGE THE FORMAT OF THE TARGET VARIABLE KNOWN AS 'user_verified' TO INTS
dataset["user_verified"] = dataset["user_verified"].astype(int)

# %% [markdown]
# **Visualise the Data**
#
# In this step we'll use a histograph to display the tweet lengths, a countplot for the number of verified and unverfied users, a correlation graph, a histograph displaying the number of tweets per month, and a scatterplot that displays the amount of tweets that have been saved and shared by users.

# %%
import plotly.express as px # PLOTLY EXPRESS (PX) IS AN IMPORT FOR GENERATING DETAILED GRAPHS

# HISTOGRAPH TO SHOW THE LENGTHS OF THE TWEETS
fig = px.histogram(dataset, x=dataset['text'].str.len(),nbins=15,title='Tweets Length')
fig

# %%
# THIS COUNT GRAPH DISPLAYS ALL THE VERIFIED AND UNVERIFIED USERS
plt.figure(figsize=(10,10))
sns.countplot(x ="user_verified",data=dataset, palette="Set1")
plt.title("Verified user accounts or not")
plt.xticks([False,True],['Unverified','Verified'])
plt.show()

# %%
# THIS DISPLAYS THE CORRELATION FOR 'id' AND'is_retweet'
# SINCE THE CORRELATION OF EACH VARIABLE IS EQUAL TO 1, IT'S SUGGESTING IT IS A POSITIVE CORRELATION
plt.figure(figsize=(10,8))
sns.heatmap(dataset.drop(columns=['id','is_retweet']).corr(), square=True, annot=True)
plt.show()

# %%
# THIS HISTOGRAPH IS USED TO SHOW THE NUMBER TWEETS FOR EACH MONTH FOR 2021
import plotly.express as px
px.histogram(dataset, x="date",  nbins=100,opacity=.5,title="Tweets per Month")

# %%
# WE USE A SCATTERPLOT TO DISPLAY FOR ATTRIBUTES 'user_friends' AND 'user_favourites'  
dataset[dataset['user_friends']<3000][dataset['user_favourites']<3000].plot.scatter(x='user_friends', y='user_favourites');
# Out:
# C:\Users\labs_service_account\AppData\Local\Temp\ipykernel_8664\1258800190.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ###  **Data Pre-Processing**

# %% [markdown]
# In this step we will take the raw data from the dataset and prepare it for our LDA analysis through convertion of the raw data

# %% [markdown]
# **Stop Words**
#
# We remove common words in the dataset, known as Stop Words, because these words will be ignored by typical tokenizers and in our analysis

# %%
import string # THIS IMPORT ALLOWS US TO SPLIT THE STRING INTO WORDS
import nltk # USED FOR PROCESSING TEXT DATA FROM TEXT-BASED DATASETS
from nltk.corpus import stopwords # THIS IMPORT WILL ALLOW THESE STOP WORDS TO BE IGNORED IN OUR ANALYSIS
nltk.download('stopwords') # THIS DOWNLOADS ALL THE LISTED STOP WORDS FROM THE NLTK PACKAGE
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\labs_service_account\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# DISPLAY THE LIST OF STOP WORDS
", ".join(stopwords.words("english"))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, m
# ...

# %%
# WE DISPLAY THE TEXT DATA IN LOWER CASE
# DECLARE A VARIABLE FOR LOWER CASE DATA
dataset["text_lower"] = dataset["text"].str.lower()

# %%
# THIS REMOVES THE STOP WORDS FROM THE TEXT DATA
Stopwords = set(stopwords.words("english"))

def remove_stopwords(text):
    return " ".join([words for words in str(text).split() if words not in Stopwords])

# DECLARE A VARIABLE FOR TEXT DATA WITHOUT STOP WORDS
dataset["text_without_stopwords"] = dataset["text_lower"].apply(lambda text: remove_stopwords(text))

# %% [markdown]
# **Tokenisation**
#
# This is often used for parsing a large amount of textual data into parts to perform an analysis of the character of the text

# %%
#Code Borrowed from:
#Koteeswaren
#2021
#Text Preprocessing in NLP
#Software: Python 
#(Kaggle, link: https://www.kaggle.com/code/beinglegend/text-preprocessing-in-nlp)

from nltk.tokenize import word_tokenize # IMPORT THAT WILL SPLIT DATA INTO SMALLER PORTIONS
nltk.download('punkt') # DOWNLOAD THE TOKEN PACKAGE
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\labs_service_account\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# THAN WE TOKENISE THE TEXT DATA WITHOUT STOP WORDS
# DECLARE A VARIABLE FOR THE TOKENISED DATA
dataset["tokenisation"] = dataset["text_without_stopwords"].apply(lambda x: word_tokenize(x))

# %% [markdown]
# **Stemming**
#
# This is the process of producing morphological variants of a root/base word

# %%
# NOW WE STEM THE TOKENISED DATA
# DECLARE A VARIABLE FOR STEMMING
dataset['stemming'] = dataset['tokenisation'].apply(lambda x: remove_stopwords(x))
ps = nltk.PorterStemmer()
def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

# %% [markdown]
# **Lemmatisation**
#
# This is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item

# %%
#Code Borrowed from:
#Koteeswaren
#2021
#Text Preprocessing in NLP
#Software: Python 
#(Kaggle, link: https://www.kaggle.com/code/beinglegend/text-preprocessing-in-nlp)

from nltk.stem import WordNetLemmatizer # IMPORT FOR LEMMATISATION
nltk.download('wordnet') # DOWNLOAD THE LEMMATISATION PACKAGE

nltk.download('omw-1.4') # DOWNLOAD THIS PACKAGE
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\labs_service_account\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\labs_service_account\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# WE LEMMATISE THE STEMMED DATA
# DECLARE A VARIABLE FOR LEMMATISED DATA
dataset['lemminisation'] = dataset['stemming'].apply\
(lambda x: [WordNetLemmatizer().lemmatize(word) for word in x])

# %% [markdown]
# ###  **LDA Model Training**

# %% [markdown]
# **Setting up the X and Y**
#
# Here we set up our X and Y, the purpose for this is for future use in splitting the data

# %%
# LET X BE TEXT DATA WITHOUT STOP WORDS
X = dataset["text_without_stopwords"]

# LET y BE "user_verified"
y = dataset["user_verified"]

# %% [markdown]
# **Training and Testing**
#
# We split the dataset into two pieces, one for training and the other for testing, using the X and Y variables we just declared.

# %%
from sklearn.model_selection import train_test_split # THIS IMPORT IS USED IN SPLITING THE DATA FOR TESTING AND TRAINING

print(X.shape) # SHOWS THE SIZE OF X
print(y.shape) # SHOWS THE SIZE OF y

# THIS SPLITS THE DATA, test_size=0.3 OR 30%, AND THE TRAIN SIZE IS EQUAL TO THE REMAINING 70%
# WHY random_state=42, IS TO ENSURE THAT THE OUTPUT THAT IS RUN EACH TIME EQUALS TO THE FIRST RUN OUTPUT WHEN SPLITTING
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(X_train.shape) # SHOWS THE SIZE OF X_train
print(X_test.shape) # SHOWS THE SIZE OF X_test
print(y_train.shape) # SHOWS THE SIZE OF y_train
print(y_test.shape) # SHOWS THE SIZE OF y_test
# Out:
# (11020,)
# (11020,)
# (7714,)
# (3306,)
# (7714,)
# (3306,)

# %% [markdown]
# **Countvectorisation**
#
# This is the process of converting a collection of text documents to a vector of term or token counts

# %%
from sklearn.feature_extraction.text import CountVectorizer # IMPORT USED FOR COUNTING THE FREQUENCY OF WORDS

vect = CountVectorizer() # DECLARE THE COUNTVECTOR OBJECT
vect.fit(X_train) # PASS THE THE X_train THROUGH THE COUNTVECTOR OBJECT

# DECLARE A VARIABLE FOR THE TRANSFORMED X_train
X_train_dtm = vect.transform(X_train)

# USE THE DECLARED VARIABLE FOR VECTORISING THE X_train
X_train_dtm = vect.fit_transform(X_train)

print(type(X_train_dtm), X_train_dtm.shape) # DISPLAY THE SHAPE OF X_train_dtm

X_test_dtm = vect.transform(X_test) # DECLARE A VARIABLE FOR THE TRANSFORMED X_test
print(type(X_test_dtm), X_test_dtm.shape) # PRINT THE SIZE
# Out:
# <class 'scipy.sparse._csr.csr_matrix'> (7714, 20156)
# <class 'scipy.sparse._csr.csr_matrix'> (3306, 20156)

# %% [markdown]
# **Term Frequency–Inverse Document Frequency (tf-idf)**
#
# This is the process of quantifying words in a set of documents, by computing a score for each word to signify its importance in the document and corpus

# %%
from sklearn.feature_extraction.text import TfidfTransformer # IMPORT FOR TF-IDF

tfidf_transformer = TfidfTransformer() # DECLARE THE TF-IDF OBJECT
tfidf_transformer.fit(X_train_dtm) # PASS THE COUNTVECTORISED X_train_dtm WITH TF-IDF
tfidf_transformer.transform(X_train_dtm) # TRANSFORM THE COUNTVECTORISED X_train_dtm WITH TF-IDF
# Out:
# <7714x20156 sparse matrix of type '<class 'numpy.float64'>'
# 	with 99467 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ###  **Analysing LDA Model Results**

# %% [markdown]
# **Pipeline**
#
# This means performing multiple operations in a sequence, for each element of an iterable, in such a way that the output of each element is the input of the next.

# %%
from sklearn.pipeline import Pipeline # IMPORT THE PIPELINE LIBRARY
from sklearn.naive_bayes import MultinomialNB # IMPORT THE GaussianNB LIBRARY

# DECLARE THE PIPELINE OBJECT BY PASSING THROUGH THE CountVectorizer, TfidfTransformer AND MultinomialNB OBJECTS
pipe = Pipeline([
    ('count_vector', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('nb', MultinomialNB())
])

# %%
# FIT THE PIPELINE WITH X_train & y_train
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('count_vector', CountVectorizer()),
#                 ('tfidf', TfidfTransformer()), ('nb', MultinomialNB())])

# %%
# THE PIPELINE SCORE SCORES AND PREDICTS THE SPLIT DATA
# THE PIPELINE SCORE HAS A 0.912 ACCURACY
pipe.score(X_test, y_test)
# Out:
# 0.91167574107683

# %%
# DECLARE A VARIABLE FOR PREDICTIONS
predictions = pipe.predict(X_test)

# %%
# WE DETERMINE THE ACCURACY OF THE PREDICTIONS
from sklearn import metrics # IMPORT FOR EVALUATING THE MODEL

print("=======Accuracy Score===========") # PRINTS THE ACCURACY SCORE FOR PREDICTIONS
print(metrics.accuracy_score(y_test, predictions))

print("=======Confision Matrix===========") # DISPLAYS THE PREDICTIONS IN A CONFUSION MATRIX
metrics.confusion_matrix(y_test, predictions)
# Out:
# =======Accuracy Score===========
# 0.91167574107683
# =======Confision Matrix===========
# array([[3014,    0],
#        [ 292,    0]], dtype=int64)

# %%
# THAN WE GENERATE A CLASSIFICATION REPORT THAT WILL DISPLAY THE PRECISION, RECALL, F1 SCORES
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions)) # WE PASS THROUGH THE y_test AND predictions
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      3014
#            1       0.00      0.00      0.00       292
#
#     accuracy                           0.91      3306
#    macro avg       0.46      0.50      0.48      3306
# weighted avg       0.83      0.91      0.87      3306
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# ...
